# %% [markdown]
# ![CapaJupyter.png](attachment:CapaJupyter.png)
#
# # Universidade dos Dados
# GitHub: http://www.github.com/unidados/
#
# Site de dicas: https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
#
# Curta a nossa página no Facebook e fique por dentro das atualizações: <a href=http://facebook.com/universidadedosdados>Universidade dos Dados</a>

# %% [markdown]
# # Aprofundando em series

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
colunas_filmes = ['star_rating','title','content_rating','genre','duration','actors_list']

file="C:/Users/Vini Estudos/Documents/Cursos e Estudos/CursoDataScience/Projetos_DataScience/20250502 - Pandas - Filmes_Diarias/movies.csv"
filmes = pd.read_csv(file, header=0, names=colunas_filmes)
filmes.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
filmes.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#Examinando os tipos
filmes.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# # Explorando series numéricas

# %%
filmes.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
#Retirando a média de duração

filmes.duration.mean()
# Out:
# 120.97957099080695

# %%
filmes.genre.value_counts()
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %%
#Podemos utilizar também o value_counts() para dados não categóricos

filmes.duration.value_counts()
# Out:
# duration
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
#        ..
# 67      1
# 195     1
# 76      1
# 66      1
# 205     1
# Name: count, Length: 133, dtype: int64

# %% [markdown]
# # Plotando Histograma e Gráfico de Barras

# %%
# %matplotlib inline

# %%
filmes.duration.plot(kind='hist')
plt.show()

# %%
filmes.genre.value_counts().plot(kind='bar')
plt.show()

# %%
ax = filmes.duration.plot(kind='hist', bins=25, color='green')
ax.set_title('Distribuição das Durações dos Filmes')
ax.set_xlabel('Duração (minutos)')
ax.set_ylabel('Frequência')
plt.show()
